# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

driver=webdriver.Chrome(executable_path="C:\\Users\\aysha\\Downloads\\DSA(Lab1)\\chromedriver\\chromedriver.exe")

Names=[]
Reviews = []
Address = []
for i in range(29975,40000,25):
    url='https://www.booking.com/searchresults.en-gb.html?label=gen173nr-1DCAEoggI46AdIM1gEaLUBiAEBmAExuAEXyAEM2AED6AEB-AECiAIBqAIDuALC9raLBsACAdICJDMxNmVjYmRkLTY0NzktNGI0Yi04MGUwLWY1MTU4ZTc4YjY3NNgCBOACAQ&sid=0124cc859e8c626f15d29510c8bee3e6&aid=304142&sb=1&src=searchresults&src_elem=sb&error_url=https%3A%2F%2Fwww.booking.com%2Fsearchresults.en-gb.html%3Faid%3D304142%3Blabel%3Dgen173nr-1DCAEoggI46AdIM1gEaLUBiAEBmAExuAEXyAEM2AED6AEB-AECiAIBqAIDuALC9raLBsACAdICJDMxNmVjYmRkLTY0NzktNGI0Yi04MGUwLWY1MTU4ZTc4YjY3NNgCBOACAQ%3Bsid%3D0124cc859e8c626f15d29510c8bee3e6%3Btmpl%3Dsearchresults%3Bac_click_type%3Db%3Bac_position%3D0%3Bcheckin_month%3D11%3Bcheckin_monthday%3D1%3Bcheckin_year%3D2021%3Bcheckout_month%3D11%3Bcheckout_monthday%3D3%3Bcheckout_year%3D2021%3Bcity%3D20088325%3Bclass_interval%3D1%3Bdest_id%3D-782831%3Bdest_type%3Dcity%3Bdtdisc%3D0%3Bfrom_sf%3D1%3Bgroup_adults%3D2%3Bgroup_children%3D0%3Biata%3DDXB%3Binac%3D0%3Bindex_postcard%3D0%3Blabel_click%3Dundef%3Bno_rooms%3D1%3Boffset%3D0%3Bpostcard%3D0%3Braw_dest_type%3Dcity%3Broom1%3DA%252CA%3Bsb_price_type%3Dtotal%3Bsb_travel_purpose%3Dbusiness%3Bsearch_selected%3D1%3Bshw_aparth%3D1%3Bslp_r_match%3D0%3Bsrc%3Dsearchresults%3Bsrc_elem%3Dsb%3Bsrpvid%3D013a637dc8070014%3Bss%3DDubai%252C%2BDubai%2BEmirate%252C%2BUnited%2BArab%2BEmirates%3Bss_all%3D0%3Bss_raw%3DDubai%3Bssb%3Dempty%3Bsshis%3D0%3Bssne%3DNew%2BYork%3Bssne_untouched%3DNew%2BYork%3Btop_ufis%3D1%3Bsig%3Dv1l1hoIoXp%26%3B&ss=India&is_ski_area=&ssne=Dubai&ssne_untouched=Dubai&city=-782831&checkin_year=2021&checkin_month=11&checkin_monthday=1&checkout_year=2021&checkout_month=11&checkout_monthday=3&group_adults=2&group_children=0&no_rooms=1&sb_travel_purpose=business&sb_changed_group=1&sb_changed_destination=1&from_sf=1&ss_raw=India&ac_position=2&ac_langcode=en&ac_click_type=b&dest_id=98&dest_type=country&place_id_lat=21.8117&place_id_lon=78.4017&search_pageview_id=013a637dc8070014&search_selected=true&search_pageview_id=013a637dc8070014&ac_suggestion_list_length=5&ac_suggestion_theme_list_length=50&offset='+str(i)
    driver.get(url)
    content=driver.page_source
    soup=BeautifulSoup(content)
    print(i)
    for a in soup.findAll('div', attrs={'class': '_fe1927d9e _0811a1b54 _a8a1be610 _022ee35ec b9c27d6646 fb3c4512b4 fc21746a73'}):
        name = a.find('div',attrs={'class':'fde444d7ef _c445487e2'})
        review = a.find('div',attrs={'class':'_4abc4c3d5 _1e6021d2f _fb3ba087b _6e869d6e0'})
        address = a.find('span',attrs={'data-testid':'address'})
        try:
            name = name.text
        except:
            name = "Null"
        try:
            review = review.text
        except:
            review = "Null"
        try:
            address = address.text
        except:
            address = "Null"
        df = pd.DataFrame({'Product Name':[name], 'Product Address':[address], 'Product Reviews':[review]})
        df.to_csv('products.csv', mode='a',index=False, header=False, encoding='utf-8')
        
#driver.get('https://www.booking.com/city/za/cape-town.html?label=gen173nr-1DCAEoggI46AdIM1gEaLUBiAEBmAExuAEXyAEM2AED6AEB-AECiAIBqAIDuAL3jLWLBsACAdICJDhlMjE1ODk1LWZlN2EtNGJjNS1iMGMwLWY1NWNiOTFjNGZiOdgCBOACAQ;sid=35e8f7e4419f617e5860e97b5ccf72df;sig=v1rFww98QB')
# Out:
# 29975
# 30000
# 30025
# 30050
# 30075
# 30100
# 30125
# 30150
# 30175
# 30200
# 30225
# 30250
# 30275
# 30300
# 30325
# 30350
# 30375
# 30400
# 30425
# 30450
# 30475
# 30500
# 30525
# 30550
# 30575
# 30600
# 30625
# 30650
# 30675
# 30700
# 30725
# 30750
# 30775
# 30800
# 30825
# 30850
# 30875
# 30900
# 30925
# 30950
# 30975
# 31000
# 31025
# 31050
# 31075
# 31100
# 31125
# 31150
# 31175
# 31200
# 31225
# 31250
# 31275
# 31300
# 31325
# 31350
# 31375
# 31400
# 31425
# 31450
# 31475
# 31500
# 31525
# 31550
# 31575
# 31600
# 31625
# 31650
# 31675
# 31700
# 31725
# 31750
# 31775
# 31800
# 31825
# 31850
# 31875
# 31900
# 31925
# 31950
# 31975
# 32000
# 32025
# 32050
# 32075
# 32100
# 32125
# 32150
# 32175
# 32200
# 32225
# 32250
# 32275
# 32300
# 32325
# 32350
# 32375
# 32400
# 32425
# 32450
# 32475
# 32500
# 32525
# 32550
# 32575
# 32600
# 32625
# 32650
# 32675
# 32700
# 32725
# 32750
# 32775
# 32800
# 32825
# 32850
# 32875
# 32900
# 32925
# 32950
# 32975
# 33000
# 33025
# 33050
# 33075
# ...

# %%
name=a.find('dh2', attrs={'class':'sr-card__name u-margin:0 u-padding:0'})
        address = a.find('div',attrs={'class':' sr-card__item__content  '})
        reviews = a.find('div',attrs={'class':'bui-review-score__text'})
        print("Name: "+name.text)
        print("Location : "+address.text[0:len(address.text)-14])
        print("Reviews: "+reviews.text)
        Names.append(name.text)
        Reviews.append(reviews.text)
        Address.append(address.text[0:len(address.text)-14])
        df = pd.DataFrame({'Product Name':[names], 'Product Address':[address], 'Product Reviews':[reviews]})
        df.to_csv('products.csv', mode='a',index=False, header=False, encoding='utf-8')
